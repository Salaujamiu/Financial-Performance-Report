# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Monthly_Financial_Report_2024.csv")
df
# Out:
#        Month  Department  Revenue_NGN  Expenses_NGN          Category  \
# 0   Jan-2024       Sales      3719110       1371155   Core Operations
# 1   Jan-2024  Operations      3729084       2114414   Core Operations
# 2   Jan-2024       Admin            0        959178  Support Services
# 3   Jan-2024     Finance            0       2392743  Support Services
# 4   Jan-2024          IT            0        810268  Support Services
# 5   Feb-2024       Sales      2232180       1803462   Core Operations
# 6   Feb-2024  Operations      3734489       1699890   Core Operations
# 7   Feb-2024       Admin            0       2270006  Support Services
# 8   Feb-2024     Finance            0       1836074  Support Services
# 9   Feb-2024          IT            0       1612756  Support Services
# 10  Mar-2024       Sales      3772355       1939911   Core Operations
# 11  Mar-2024  Operations      1778167        741090   Core Operations
# ...

# %%
# Preview the first few row
df.head()
# Out:
#       Month  Department  Revenue_NGN  Expenses_NGN          Category  \
# 0  Jan-2024       Sales      3719110       1371155   Core Operations
# 1  Jan-2024  Operations      3729084       2114414   Core Operations
# 2  Jan-2024       Admin            0        959178  Support Services
# 3  Jan-2024     Finance            0       2392743  Support Services
# 4  Jan-2024          IT            0        810268  Support Services
#
#    Profit_NGN  Profit_Margin_%
# 0     2347955        63.132174
# 1     1614670        43.299373
# 2     -959178         0.000000
# 3    -2392743         0.000000
# 4     -810268         0.000000

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Month            60 non-null     object
#  1   Department       60 non-null     object
#  2   Revenue_NGN      60 non-null     int64
#  3   Expenses_NGN     60 non-null     int64
#  4   Category         60 non-null     object
#  5   Profit_NGN       60 non-null     int64
#  6   Profit_Margin_%  60 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.4+ KB
#         Revenue_NGN  Expenses_NGN    Profit_NGN  Profit_Margin_%
# count  6.000000e+01  6.000000e+01  6.000000e+01        60.000000
# mean   1.179235e+06  1.589183e+06 -4.099479e+05        16.680565
# std    1.536912e+06  4.903423e+05  1.610409e+06        27.043171
# min    0.000000e+00  7.410900e+05 -2.473415e+06       -19.980009
# 25%    0.000000e+00  1.217649e+06 -1.720426e+06         0.000000
# ...

# %%
# Any missing values?
df.isnull().sum()

# Check unique departments and months
df['Department'].unique()
df['Month'].unique()
# Out:
# array(['Jan-2024', 'Feb-2024', 'Mar-2024', 'Apr-2024', 'May-2024',
#        'Jun-2024', 'Jul-2024', 'Aug-2024', 'Sep-2024', 'Oct-2024',
#        'Nov-2024', 'Dec-2024'], dtype=object)

# %%
df["Month"] = pd.to_datetime(df["Month"], format="%b-%Y")

# %%
total_revenue = df["Revenue_NGN"].sum()
total_expenses = df["Expenses_NGN"].sum()
total_profit = df["Profit_NGN"].sum()
average_margin = df["Profit_Margin_%"].mean()

print("Total Revenue: ₦{:,.0f}".format(total_revenue))
print("Total Expenses: ₦{:,.0f}".format(total_expenses))
print("Total Profit: ₦{:,.0f}".format(total_profit))
print("Average Profit Margin: {:.2f}%".format(average_margin))
# Out:
# Total Revenue: ₦70,754,081
# Total Expenses: ₦95,350,955
# Total Profit: ₦-24,596,874
# Average Profit Margin: 16.68%

# %%
monthly_summary = df.groupby("Month")[["Revenue_NGN", "Expenses_NGN", "Profit_NGN"]].sum().reset_index()
monthly_summary
# Out:
#         Month  Revenue_NGN  Expenses_NGN  Profit_NGN
# 0  2024-01-01      7448194       7647758     -199564
# 1  2024-02-01      5966669       9222188    -3255519
# 2  2024-03-01      5550522       7010963    -1460441
# 3  2024-04-01      4697524       8693978    -3996454
# 4  2024-05-01      5658777       7938303    -2279526
# 5  2024-06-01      6170922       8861944    -2691022
# 6  2024-07-01      3713868       7809153    -4095285
# 7  2024-08-01      7786872       6792323      994549
# 8  2024-09-01      6752025       8535465    -1783440
# 9  2024-10-01      6291354       7102699     -811345
# 10 2024-11-01      4153450       7248238    -3094788
# 11 2024-12-01      6563904       8487943    -1924039

# %%
department_summary = df.groupby("Department")[["Revenue_NGN", "Expenses_NGN", "Profit_NGN"]].sum().reset_index()
department_summary
# Out:
#    Department  Revenue_NGN  Expenses_NGN  Profit_NGN
# 0       Admin            0      18764760   -18764760
# 1     Finance            0      19946086   -19946086
# 2          IT            0      18549947   -18549947
# 3  Operations     35832696      18145855    17686841
# 4       Sales     34921385      19944307    14977078

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_summary, x="Month", y="Revenue_NGN", label="Revenue")
sns.lineplot(data=monthly_summary, x="Month", y="Expenses_NGN", label="Expenses")
plt.title("Monthly Revenue vs Expenses")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Revenue Vs Expenses.png")
plt.show()

# %% [markdown]
# # Monthly Revenue vs Expenses
#
# ### Revenue showed fluctuations across the year, with the lowest point in July 2024 and noticeable rebounds in August and December.
# ### Expenses remained consistently higher than revenue in most months, suggesting operational inefficiencies or underperformance in revenue generation.
# ### The gap between revenue and expenses was narrowest in August — potentially indicating a period of better cost control or improved income

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=department_summary, x="Department", y="Profit_NGN", palette="viridis")
plt.title("Total Profit by Department")
plt.ylabel("Profit (₦)")
plt.tight_layout()
plt.savefig("Profit_department.png")
plt.show()
# Out:
# C:\Users\salaudeen.j\AppData\Local\Temp\ipykernel_27424\2716844730.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=department_summary, x="Department", y="Profit_NGN", palette="viridis")

# %% [markdown]
# # Total Profit by Department
# Profitability analysis by department reveals that:
#
# Operations and Sales are the primary profit drivers, each generating over ₦15 million in profit.
#
# In contrast, Admin, Finance, and IT all posted negative profits (losses), with IT and Admin incurring losses above ₦18 million each.
#
# This reflects typical overhead behavior in support departments, but the extent of losses may indicate a need for tighter cost control or cost-benefit review.

# %%
monthly_margin = df.groupby("Month")["Profit_Margin_%"].mean().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_margin, x="Month", y="Profit_Margin_%", marker="o", color="darkgreen")
plt.title("Average Monthly Profit Margin")
plt.ylabel("Margin (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("monthly_margin.png")
plt.show()

# %% [markdown]
# # Average Monthly Profit Margin
# Profit margins were highly volatile throughout the year.
# A sharp dip occurred in April and July, with July recording a negative margin (loss) — possibly due to peak expenses and low revenue.
# Margins recovered significantly in August, September, and October, with October seeing the highest margin for the year at over 26%.
# The Q3 recovery could indicate strategic adjustments or seasonal business improvements

# %%
# !jupyter nbconvert "Report.ipynb" --to html
# Out:
# [NbConvertApp] Converting notebook Report.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 3 image(s).
# [NbConvertApp] Writing 514141 bytes to Report.html
